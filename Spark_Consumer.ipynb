# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import split
from pyspark.sql.types import *
from confluent_kafka import Consumer

conf = {'bootstrap.servers': "localhost:9092",
        'group.id': "foo",
        'auto.offset.reset': 'smallest'}

consumer = Consumer(conf)

# %%
consumer

# %%
# Create a SparkSession
spark = SparkSession.builder \
    .appName("KafkaStreamReader") \
    .getOrCreate()

# %%
# Define the schema for the DataFrame
schema = StructType([
    StructField("TvC", StringType(), nullable=False),
    StructField("date", StringType(), nullable=False),
    StructField("traffic_source", StringType(), nullable=False),
    StructField("device_type", StringType(), nullable=False),
    StructField("browser_language", StringType(), nullable=False),
    StructField("login_y_n", StringType(), nullable=False),
    StructField("region", StringType(), nullable=False),
    StructField("return_y_n", StringType(), nullable=False),
    StructField("conversion", StringType(), nullable=False)
])

# Define the column names
column_names = ['TvC', 'date', 'traffic_source', 'device_type', 'browser_language', 'login_y_n', 'region', 'return_y_n', 'conversion']

#Creates Empty RDD
emptyRDD = spark.sparkContext.emptyRDD()

#Create empty DataFrame from empty RDD
df = spark.createDataFrame(emptyRDD,schema)

df.printSchema()
# Out:
# root
#  |-- TvC: string (nullable = false)
#  |-- date: string (nullable = false)
#  |-- traffic_source: string (nullable = false)
#  |-- device_type: string (nullable = false)
#  |-- browser_language: string (nullable = false)
#  |-- login_y_n: string (nullable = false)
#  |-- region: string (nullable = false)
#  |-- return_y_n: string (nullable = false)
#  |-- conversion: string (nullable = false)

# %%
import csv

running = True

def basic_consume_loop(consumer, topics, df):
    try:
        consumer.subscribe(topics)

        while running:
            msg = consumer.poll(timeout=3.0)
            if msg is None: continue

            if msg.error():
                if msg.error().code() == KafkaError._PARTITION_EOF:
                    # End of partition event
                    sys.stderr.write('%% %s [%d] reached end at offset %d\n' %
                                     (msg.topic(), msg.partition(), msg.offset()))
                elif msg.error():
                    raise KafkaException(msg.error())
            else:
                print(msg.topic(), msg.partition(), msg.offset(), msg.key(), msg.value().decode('utf-8'))
                print('==========')
                
                # Split the row string into a list of values
                row_values = msg.value().decode('utf-8').split(",")
                
                # Check if the message has the correct number of values
                if len(row_values) != len(column_names):
                    print(f"Skipping malformed message: {msg.value().decode('utf-8')}")
                    continue

                # Convert the list of values to a single-row DataFrame
                row_df = spark.createDataFrame([row_values], column_names)
                
                write_to_csv(msg.value().decode('utf-8'))

                # Append the row DataFrame to the main DataFrame
                df = df.union(row_df)
                
                # Show the resulting DataFrame
                #df.show()
    finally:
        # Close down consumer to commit final offsets.
        consumer.close()

def shutdown():
    running = False
    
def write_to_csv(new_row):
    # Define the CSV file path
    csv_file = 'Data/data.csv'

    # Define the column names
    fieldnames = ['TvC', 'date', 'traffic_source', 'device_type', 'browser_language', 'login_y_n', 'region', 'return_y_n', 'conversion']

    # Check if the file exists
    file_exists = os.path.isfile(csv_file)

    # Open the file in append mode and write the header if the file is empty
    with open(csv_file, 'a', newline='') as file:
    
        writer = csv.DictWriter(file, fieldnames=fieldnames)

        # Check if the file is empty
        file.seek(0)
        #is_empty = len(file.read()) == 0

        if not file_exists:
            writer.writeheader()
        
        # Split the input and create a dictionary using fieldnames as keys
        row_data = dict(zip(fieldnames, new_row.split(',')))

        # Write the new row to the CSV file
        writer.writerow(row_data)

    print("Rows added to the CSV file.")

# %%
basic_consume_loop(consumer, ['sparkab'], df)
# Out:
# sparkab 0 391 None C,2021-02-06,Email Marketing,Android,Spanish,n,Southwest,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 392 None C,2021-02-07,Organic,Iphone,English,n,West,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 393 None V1,2021-02-16,Organic,Desktop,English,y,Southeast,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 394 None C,2021-02-04,Referrals,Mweb,English,n,Northeast,y,1
# ==========
# Rows added to the CSV file.
# sparkab 0 395 None C,2021-02-13,Social Media,Mweb,Spanish,y,Southeast,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 396 None V1,2021-02-04,Direct,Desktop,Spanish,n,Southwest,y,1
# ==========
# Rows added to the CSV file.
# sparkab 0 397 None V1,2021-02-11,Organic,Iphone,English,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 398 None C,2021-02-07,Organic,Iphone,English,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 399 None C,2021-02-07,Social Media,Mweb,Other,y,Northeast,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 400 None C,2021-02-10,Direct,Android,English,n,Southwest,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 401 None V1,2021-02-07,Referrals,Mweb,English,n,West,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 402 None C,2021-02-02,Referrals,Mweb,Spanish,y,Midwest,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 403 None C,2021-02-01,Organic,Desktop,Spanish,n,Southwest,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 404 None C,2021-02-09,Organic,Mweb,English,n,Southwest,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 405 None C,2021-02-01,Organic,Android,English,y,Southeast,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 406 None V1,2021-02-15,Direct,Iphone,Chinese,n,West,y,1
# ==========
# Rows added to the CSV file.
# sparkab 0 407 None V1,2021-02-08,Direct,Mweb,Spanish,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 408 None V1,2021-02-09,Referrals,Iphone,French,n,Southwest,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 409 None C,2021-02-06,Direct,Iphone,Spanish,y,West,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 410 None C,2021-02-10,Direct,Desktop,English,n,Southeast,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 411 None C,2021-02-12,Organic,Desktop,English,n,Midwest,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 412 None C,2021-02-02,Referrals,Iphone,English,y,Southwest,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 413 None V1,2021-02-13,Referrals,Mweb,English,y,Northeast,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 414 None V1,2021-02-01,Direct,Mweb,English,y,Northeast,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 415 None V1,2021-02-12,Direct,Iphone,English,y,Northeast,y,1
# ==========
# Rows added to the CSV file.
# sparkab 0 416 None V1,2021-02-02,Direct,Desktop,English,n,Midwest,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 417 None C,2021-02-10,Organic,Desktop,English,n,Northeast,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 418 None C,2021-02-02,Organic,Iphone,French,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 419 None V1,2021-02-13,Organic,Iphone,Spanish,y,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 420 None V1,2021-02-15,Organic,Mweb,English,y,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 421 None V1,2021-02-07,Organic,Iphone,English,n,Midwest,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 422 None V1,2021-02-02,Organic,Desktop,English,n,Northeast,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 423 None V1,2021-02-08,Referrals,Desktop,English,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 424 None C,2021-02-02,Paid Search,Mweb,Spanish,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 425 None V1,2021-02-01,Paid Search,Desktop,Spanish,n,Northeast,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 426 None V1,2021-02-03,Social Media,Iphone,Spanish,y,Northeast,y,1
# ==========
# Rows added to the CSV file.
# sparkab 0 427 None C,2021-02-14,Paid Search,Iphone,Spanish,n,Southeast,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 428 None C,2021-02-06,Organic,Mweb,English,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 429 None V1,2021-02-14,Email Marketing,Mweb,English,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 430 None C,2021-02-13,Organic,Android,English,y,Southeast,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 431 None C,2021-02-04,Organic,Mweb,English,n,Midwest,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 432 None C,2021-02-10,Direct,Desktop,English,n,Northeast,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 433 None C,2021-02-06,Direct,Iphone,Spanish,n,Northeast,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 434 None C,2021-02-01,Organic,Desktop,English,n,Northeast,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 435 None V1,2021-02-14,Referrals,Mweb,English,n,West,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 436 None V1,2021-02-07,Paid Search,Mweb,English,n,Northeast,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 437 None C,2021-02-14,Paid Search,Mweb,English,n,West,n,1
# ==========
# Rows added to the CSV file.
# sparkab 0 438 None V1,2021-02-04,Email Marketing,Desktop,English,y,Southwest,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 439 None C,2021-02-01,Direct,Desktop,English,n,Southwest,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 440 None C,2021-02-10,Paid Search,Mweb,Spanish,y,West,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 441 None C,2021-02-10,Direct,Desktop,English,y,West,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 442 None V1,2021-02-06,Organic,Desktop,English,n,Northeast,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 443 None V1,2021-02-07,Organic,Desktop,English,n,Southwest,n,1
# ==========
# Rows added to the CSV file.
# sparkab 0 444 None C,2021-02-10,Referrals,Desktop,English,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 445 None C,2021-02-14,Organic,Mweb,English,n,West,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 446 None V1,2021-02-02,Referrals,Desktop,English,y,Midwest,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 447 None V1,2021-02-06,Organic,Mweb,Spanish,y,Northeast,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 448 None C,2021-02-13,Email Marketing,Desktop,Spanish,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 449 None C,2021-02-15,Referrals,Desktop,English,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 450 None C,2021-02-08,Direct,Mweb,Other,n,Northeast,y,1
# ==========
# Rows added to the CSV file.
# sparkab 0 451 None C,2021-02-08,Organic,Mweb,English,n,West,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 452 None C,2021-02-04,Organic,Mweb,English,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 453 None C,2021-02-08,Organic,Android,English,y,Northeast,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 454 None C,2021-02-16,Organic,Desktop,English,n,Southwest,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 455 None C,2021-02-08,Direct,Mweb,Spanish,y,Southeast,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 456 None V1,2021-02-14,Email Marketing,Mweb,English,n,West,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 457 None V1,2021-02-03,Social Media,Desktop,Other,n,Southwest,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 458 None V1,2021-02-03,Direct,Mweb,Other,y,Midwest,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 459 None V1,2021-02-12,Referrals,Mweb,English,y,Midwest,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 460 None V1,2021-02-07,Social Media,Desktop,English,y,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 461 None C,2021-02-13,Organic,Mweb,English,y,Northeast,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 462 None C,2021-02-16,Organic,Mweb,English,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 463 None V1,2021-02-14,Paid Search,Desktop,English,n,Southwest,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 464 None V1,2021-02-05,Organic,Mweb,English,y,Southwest,n,1
# ==========
# Rows added to the CSV file.
# sparkab 0 465 None C,2021-02-14,Social Media,Mweb,English,n,West,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 466 None V1,2021-02-04,Organic,Desktop,English,y,Southwest,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 467 None V1,2021-02-09,Organic,Mweb,English,n,Southwest,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 468 None V1,2021-02-01,Organic,Desktop,English,n,Southwest,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 469 None V1,2021-02-07,Email Marketing,Mweb,English,n,Southeast,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 470 None C,2021-02-02,Direct,Mweb,Spanish,y,West,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 471 None C,2021-02-11,Organic,Android,English,n,West,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 472 None C,2021-02-09,Direct,Iphone,Spanish,n,Southeast,n,1
# ==========
# Rows added to the CSV file.
# sparkab 0 473 None V1,2021-02-12,Social Media,Iphone,Spanish,n,Southwest,y,1
# ==========
# Rows added to the CSV file.
# sparkab 0 474 None V1,2021-02-13,Direct,Desktop,Spanish,y,West,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 475 None C,2021-02-16,Email Marketing,Mweb,English,y,West,n,0
# ==========
# Rows added to the CSV file.
# sparkab 0 476 None V1,2021-02-13,Direct,Desktop,Spanish,n,West,y,1
# ==========
# Rows added to the CSV file.
# sparkab 0 477 None C,2021-02-07,Organic,Mweb,English,n,Southeast,y,0
# ==========
# Rows added to the CSV file.
# sparkab 0 478 None C,2021-02-07,Organic,Desktop,English,n,West,y,1
# ==========
# Rows added to the CSV file.
# sparkab 0 479 None V1,2021-02-01,Direct,Iphone,English,n,Southwest,y,0
# ==========
# Rows added to the CSV file.
